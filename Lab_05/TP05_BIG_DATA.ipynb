# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive

# Set the base path to your lab folder in Drive
base_path = "/content/drive/MyDrive/"
station_path = base_path + "station_data.csv"
trip_path    = base_path + "trip_data.csv"

# %% [markdown]
# Install required packages

# %%
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !pip install pyspark
# !pip install graphframes
# !pip install tqdm
# Out:
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/o/openjdk-lts/openjdk-11-jre-headless_11.0.28%2b6-1ubuntu1%7e22.04.1_amd64.deb  404  Not Found [IP: 185.125.190.82 80]
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/main/o/openjdk-lts/openjdk-11-jdk-headless_11.0.28%2b6-1ubuntu1%7e22.04.1_amd64.deb  404  Not Found [IP: 185.125.190.82 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?
# Requirement already satisfied: pyspark in /usr/local/lib/python3.12/dist-packages (3.5.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.12/dist-packages (from pyspark) (0.10.9.7)
# Collecting graphframes
#   Downloading graphframes-0.6-py2.py3-none-any.whl.metadata (934 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from graphframes) (2.0.2)
# Collecting nose (from graphframes)
#   Downloading nose-1.3.7-py3-none-any.whl.metadata (1.7 kB)
# Downloading graphframes-0.6-py2.py3-none-any.whl (18 kB)
# Downloading nose-1.3.7-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.7/154.7 kB 3.9 MB/s eta 0:00:00
# Installing collected packages: nose, graphframes
# Successfully installed graphframes-0.6 nose-1.3.7
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)

# %% [markdown]
# Imports and device setup

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from pyspark.sql import SparkSession
from pyspark.sql.functions import desc, lit
from graphframes import GraphFrame
from tqdm.notebook import tqdm

# Device agnostic for PyTorch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %% [markdown]
# Start SparkSession

# %%
spark = SparkSession.builder \
    .appName("TP05_GraphFrames") \
    .config("spark.jars.packages", "graphframes:graphframes:0.8.2-spark3.1-s_2.12") \
    .getOrCreate()

print("Spark session started. Version:", spark.version)
# Out:
# Spark session started. Version: 3.5.1

# %% [markdown]
# Load CSV files

# %%
stations_df = spark.read.csv(station_path, header=True, inferSchema=True)
trips_df    = spark.read.csv(trip_path, header=True, inferSchema=True)

stations_df.show(5, truncate=False)
trips_df.show(5, truncate=False)
# Out:
# +----------+---------------------------------+---------+-----------+---------+--------+------------+
# |station_id|name                             |lat      |long       |dockcount|landmark|installation|
# +----------+---------------------------------+---------+-----------+---------+--------+------------+
# |2         |San Jose Diridon Caltrain Station|37.329732|-121.901782|27       |San Jose|8/6/2013    |
# |3         |San Jose Civic Center            |37.330698|-121.888979|15       |San Jose|8/5/2013    |
# |4         |Santa Clara at Almaden           |37.333988|-121.894902|11       |San Jose|8/6/2013    |
# |5         |Adobe on Almaden                 |37.331415|-121.8932  |19       |San Jose|8/5/2013    |
# |6         |San Pedro Square                 |37.336721|-121.894074|15       |San Jose|8/7/2013    |
# +----------+---------------------------------+---------+-----------+---------+--------+------------+
# only showing top 5 rows
#
# +-------+--------+---------------+------------------------------------+--------------+---------------+----------------------------------------+------------+------+---------------+--------+
# |Trip ID|Duration|Start Date     |Start Station                       |Start Terminal|End Date       |End Station                             |End Terminal|Bike #|Subscriber Type|Zip Code|
# +-------+--------+---------------+------------------------------------+--------------+---------------+----------------------------------------+------------+------+---------------+--------+
# |913460 |765     |8/31/2015 23:26|Harry Bridges Plaza (Ferry Building)|50            |8/31/2015 23:39|San Francisco Caltrain (Townsend at 4th)|70          |288   |Subscriber     |2139    |
# |913459 |1036    |8/31/2015 23:11|San Antonio Shopping Center         |31            |8/31/2015 23:28|Mountain View City Hall                 |27          |35    |Subscriber     |95032   |
# |913455 |307     |8/31/2015 23:13|Post at Kearny                      |47            |8/31/2015 23:18|2nd at South Park                       |64          |468   |Subscriber     |94107   |
# |913454 |409     |8/31/2015 23:10|San Jose City Hall                  |10            |8/31/2015 23:17|San Salvador at 1st                     |8           |68    |Subscriber     |95113   |
# |913453 |789     |8/31/2015 23:09|Embarcadero at Folsom               |51            |8/31/2015 23:22|Embarcadero at Sansome                  |60          |487   |Customer       |9069    |
# +-------+--------+---------------+------------------------------------+--------------+---------------+----------------------------------------+------------+------+---------------+--------+
# only showing top 5 rows

# %% [markdown]
# Prepare vertices and edges for GraphFrame

# %%
# Vertices: rename 'name' -> 'id'
vertices = stations_df.withColumnRenamed("name", "id")
vertices.show(5, truncate=False)

# Edges: rename 'Start Station' -> 'src', 'End Station' -> 'dst'
edges = trips_df.withColumnRenamed("Start Station", "src") \
                .withColumnRenamed("End Station", "dst")
edges.show(5, truncate=False)
# Out:
# +----------+---------------------------------+---------+-----------+---------+--------+------------+
# |station_id|id                               |lat      |long       |dockcount|landmark|installation|
# +----------+---------------------------------+---------+-----------+---------+--------+------------+
# |2         |San Jose Diridon Caltrain Station|37.329732|-121.901782|27       |San Jose|8/6/2013    |
# |3         |San Jose Civic Center            |37.330698|-121.888979|15       |San Jose|8/5/2013    |
# |4         |Santa Clara at Almaden           |37.333988|-121.894902|11       |San Jose|8/6/2013    |
# |5         |Adobe on Almaden                 |37.331415|-121.8932  |19       |San Jose|8/5/2013    |
# |6         |San Pedro Square                 |37.336721|-121.894074|15       |San Jose|8/7/2013    |
# +----------+---------------------------------+---------+-----------+---------+--------+------------+
# only showing top 5 rows
#
# +-------+--------+---------------+------------------------------------+--------------+---------------+----------------------------------------+------------+------+---------------+--------+
# |Trip ID|Duration|Start Date     |src                                 |Start Terminal|End Date       |dst                                     |End Terminal|Bike #|Subscriber Type|Zip Code|
# +-------+--------+---------------+------------------------------------+--------------+---------------+----------------------------------------+------------+------+---------------+--------+
# |913460 |765     |8/31/2015 23:26|Harry Bridges Plaza (Ferry Building)|50            |8/31/2015 23:39|San Francisco Caltrain (Townsend at 4th)|70          |288   |Subscriber     |2139    |
# |913459 |1036    |8/31/2015 23:11|San Antonio Shopping Center         |31            |8/31/2015 23:28|Mountain View City Hall                 |27          |35    |Subscriber     |95032   |
# |913455 |307     |8/31/2015 23:13|Post at Kearny                      |47            |8/31/2015 23:18|2nd at South Park                       |64          |468   |Subscriber     |94107   |
# |913454 |409     |8/31/2015 23:10|San Jose City Hall                  |10            |8/31/2015 23:17|San Salvador at 1st                     |8           |68    |Subscriber     |95113   |
# |913453 |789     |8/31/2015 23:09|Embarcadero at Folsom               |51            |8/31/2015 23:22|Embarcadero at Sansome                  |60          |487   |Customer       |9069    |
# +-------+--------+---------------+------------------------------------+--------------+---------------+----------------------------------------+------------+------+---------------+--------+
# only showing top 5 rows

# %% [markdown]
# Create GraphFrame

# %%
g = GraphFrame(vertices, edges)

print("Number of stations:", g.vertices.count())
print("Number of trips:", g.edges.count())
# Out:
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/dataframe.py:168: UserWarning: DataFrame.sql_ctx is an internal property, and will be removed in future releases. Use DataFrame.sparkSession instead.
#   warnings.warn(
# Number of stations: 70
# Number of trips: 99

# %% [markdown]
# Query 5: Trips count between each source-destination

# %%
trip_counts = edges.groupBy("src", "dst").count().orderBy(desc("count"))
trip_counts.show(50, truncate=False)
# Out:
# +---------------------------------------------+---------------------------------------------+-----+
# |src                                          |dst                                          |count|
# +---------------------------------------------+---------------------------------------------+-----+
# |San Francisco Caltrain 2 (330 Townsend)      |Townsend at 7th                              |4    |
# |5th at Howard                                |San Francisco Caltrain 2 (330 Townsend)      |3    |
# |San Francisco Caltrain 2 (330 Townsend)      |Powell Street BART                           |2    |
# |2nd at Townsend                              |Market at Sansome                            |2    |
# |Spear at Folsom                              |2nd at Townsend                              |2    |
# |Market at Sansome                            |Broadway St at Battery St                    |2    |
# |Davis at Jackson                             |Embarcadero at Sansome                       |2    |
# |San Francisco Caltrain 2 (330 Townsend)      |2nd at South Park                            |2    |
# |Steuart at Market                            |San Francisco Caltrain (Townsend at 4th)     |2    |
# |Market at 4th                                |San Francisco Caltrain 2 (330 Townsend)      |2    |
# |Embarcadero at Folsom                        |Embarcadero at Sansome                       |2    |
# |Mountain View Caltrain Station               |Rengstorff Avenue / California Street        |1    |
# |Davis at Jackson                             |Temporary Transbay Terminal (Howard at Beale)|1    |
# |5th at Howard                                |Townsend at 7th                              |1    |
# |Market at Sansome                            |South Van Ness at Market                     |1    |
# |Beale at Market                              |Temporary Transbay Terminal (Howard at Beale)|1    |
# |2nd at Townsend                              |Powell at Post (Union Square)                |1    |
# |Market at Sansome                            |Clay at Battery                              |1    |
# |2nd at South Park                            |Howard at 2nd                                |1    |
# |Embarcadero at Sansome                       |Steuart at Market                            |1    |
# |South Van Ness at Market                     |Market at 4th                                |1    |
# |Yerba Buena Center of the Arts (3rd @ Howard)|San Francisco Caltrain 2 (330 Townsend)      |1    |
# |San Francisco Caltrain 2 (330 Townsend)      |Harry Bridges Plaza (Ferry Building)         |1    |
# |Townsend at 7th                              |Spear at Folsom                              |1    |
# |Howard at 2nd                                |2nd at South Park                            |1    |
# |Market at Sansome                            |San Francisco Caltrain (Townsend at 4th)     |1    |
# |Commercial at Montgomery                     |San Francisco City Hall                      |1    |
# |Market at Sansome                            |Embarcadero at Bryant                        |1    |
# |Post at Kearny                               |2nd at South Park                            |1    |
# |Steuart at Market                            |2nd at Townsend                              |1    |
# |Howard at 2nd                                |San Francisco Caltrain (Townsend at 4th)     |1    |
# |2nd at Townsend                              |Spear at Folsom                              |1    |
# |Harry Bridges Plaza (Ferry Building)         |San Francisco Caltrain (Townsend at 4th)     |1    |
# |Townsend at 7th                              |Harry Bridges Plaza (Ferry Building)         |1    |
# |Temporary Transbay Terminal (Howard at Beale)|San Francisco Caltrain 2 (330 Townsend)      |1    |
# |Yerba Buena Center of the Arts (3rd @ Howard)|Market at 10th                               |1    |
# |San Francisco Caltrain (Townsend at 4th)     |Spear at Folsom                              |1    |
# |Steuart at Market                            |Embarcadero at Sansome                       |1    |
# |Yerba Buena Center of the Arts (3rd @ Howard)|Steuart at Market                            |1    |
# |Spear at Folsom                              |Davis at Jackson                             |1    |
# |Spear at Folsom                              |San Francisco Caltrain 2 (330 Townsend)      |1    |
# |Howard at 2nd                                |Market at Sansome                            |1    |
# |Post at Kearny                               |South Van Ness at Market                     |1    |
# |Post at Kearny                               |5th at Howard                                |1    |
# |Market at 4th                                |2nd at Townsend                              |1    |
# |San Antonio Shopping Center                  |Mountain View City Hall                      |1    |
# |Market at 10th                               |San Francisco Caltrain (Townsend at 4th)     |1    |
# |Spear at Folsom                              |Townsend at 7th                              |1    |
# |San Francisco Caltrain (Townsend at 4th)     |Market at 4th                                |1    |
# |Mountain View Caltrain Station               |Castro Street and El Camino Real             |1    |
# +---------------------------------------------+---------------------------------------------+-----+
# only showing top 50 rows

# %% [markdown]
# Query 6: Trips starting or ending at 'Townsend at 7th'

# %%
station = "Townsend at 7th"

# Trips starting from the station
trips_from = edges.filter(edges.src == station).groupBy("dst").count() \
                  .withColumnRenamed("dst", "other_station") \
                  .withColumn("direction", lit("from")) \
                  .orderBy(desc("count"))

# Trips ending at the station
trips_to = edges.filter(edges.dst == station).groupBy("src").count() \
                .withColumnRenamed("src", "other_station") \
                .withColumn("direction", lit("to")) \
                .orderBy(desc("count"))

trips_from.show(50, truncate=False)
trips_to.show(50, truncate=False)
# Out:
# +------------------------------------+-----+---------+
# |other_station                       |count|direction|
# +------------------------------------+-----+---------+
# |Spear at Folsom                     |1    |from     |
# |Harry Bridges Plaza (Ferry Building)|1    |from     |
# +------------------------------------+-----+---------+
#
# +---------------------------------------+-----+---------+
# |other_station                          |count|direction|
# +---------------------------------------+-----+---------+
# |San Francisco Caltrain 2 (330 Townsend)|4    |to       |
# |Spear at Folsom                        |1    |to       |
# |5th at Howard                          |1    |to       |
# |Howard at 2nd                          |1    |to       |
# +---------------------------------------+-----+---------+

# %% [markdown]
# Query 7: Stations never a destination from 'Spear at Folsom'

# %%
src_station = "Spear at Folsom"

dsts_from_spear = edges.filter(edges.src == src_station).select("dst").distinct()
never_dest = vertices.join(dsts_from_spear, vertices.id == dsts_from_spear.dst, how="left_anti")
never_dest.show(50, truncate=False)
# Out:
# +----------+---------------------------------------------+----------+------------+---------+-------------+------------+
# |station_id|id                                           |lat       |long        |dockcount|landmark     |installation|
# +----------+---------------------------------------------+----------+------------+---------+-------------+------------+
# |2         |San Jose Diridon Caltrain Station            |37.329732 |-121.901782 |27       |San Jose     |8/6/2013    |
# |3         |San Jose Civic Center                        |37.330698 |-121.888979 |15       |San Jose     |8/5/2013    |
# |4         |Santa Clara at Almaden                       |37.333988 |-121.894902 |11       |San Jose     |8/6/2013    |
# |5         |Adobe on Almaden                             |37.331415 |-121.8932   |19       |San Jose     |8/5/2013    |
# |6         |San Pedro Square                             |37.336721 |-121.894074 |15       |San Jose     |8/7/2013    |
# |7         |Paseo de San Antonio                         |37.333798 |-121.886943 |15       |San Jose     |8/7/2013    |
# |8         |San Salvador at 1st                          |37.330165 |-121.885831 |15       |San Jose     |8/5/2013    |
# |9         |Japantown                                    |37.348742 |-121.894715 |15       |San Jose     |8/5/2013    |
# |10        |San Jose City Hall                           |37.337391 |-121.886995 |15       |San Jose     |8/6/2013    |
# |11        |MLK Library                                  |37.335885 |-121.88566  |19       |San Jose     |8/6/2013    |
# |12        |SJSU 4th at San Carlos                       |37.332808 |-121.883891 |19       |San Jose     |8/7/2013    |
# |13        |St James Park                                |37.339301 |-121.889937 |15       |San Jose     |8/6/2013    |
# |58        |San Francisco City Hall                      |37.77865  |-122.418235 |19       |San Francisco|8/21/2013   |
# |59        |Golden Gate at Polk                          |37.781332 |-122.418603 |23       |San Francisco|8/21/2013   |
# |60        |Embarcadero at Sansome                       |37.80477  |-122.403234 |15       |San Francisco|8/21/2013   |
# |62        |2nd at Folsom                                |37.785299 |-122.396236 |19       |San Francisco|8/22/2013   |
# |63        |Howard at 2nd                                |37.786978 |-122.398108 |19       |San Francisco|8/22/2013   |
# +----------+---------------------------------------------+----------+------------+---------+-------------+------------+
# only showing top 50 rows

# %% [markdown]
# Query 8: Station with max incoming trips

# %%
incoming_counts = edges.groupBy("dst").count().orderBy(desc("count"))
incoming_counts.show(10, truncate=False)

top_station = incoming_counts.limit(1)
top_station.show()
# Out:
# +----------------------------------------+-----+
# |dst                                     |count|
# +----------------------------------------+-----+
# |San Francisco Caltrain 2 (330 Townsend) |9    |
# |2nd at Townsend                         |8    |
# |Townsend at 7th                         |7    |
# |Embarcadero at Sansome                  |7    |
# |San Francisco Caltrain (Townsend at 4th)|7    |
# |Market at Sansome                       |5    |
# |Spear at Folsom                         |5    |
# |Steuart at Market                       |5    |
# |2nd at South Park                       |4    |
# |Harry Bridges Plaza (Ferry Building)    |3    |
# +----------------------------------------+-----+
# only showing top 10 rows
#
# +--------------------+-----+
# |                 dst|count|
# +--------------------+-----+
# |San Francisco Cal...|    9|
# +--------------------+-----+

# %% [markdown]
# Query 9: Trip with max duration

# %%
duration_col = "Duration"

edges.orderBy(desc(duration_col)).limit(1).show(truncate=False)
# Out:
# +-------+--------+---------------+---------------------+--------------+---------------+------------------------------------+------------+------+---------------+--------+
# |Trip ID|Duration|Start Date     |src                  |Start Terminal|End Date       |dst                                 |End Terminal|Bike #|Subscriber Type|Zip Code|
# +-------+--------+---------------+---------------------+--------------+---------------+------------------------------------+------------+------+---------------+--------+
# |913386 |1808    |8/31/2015 20:23|Embarcadero at Bryant|54            |8/31/2015 20:53|Harry Bridges Plaza (Ferry Building)|50          |524   |Subscriber     |94105   |
# +-------+--------+---------------+---------------------+--------------+---------------+------------------------------------+------------+------+---------------+--------+

# %% [markdown]
# # Query 10: Subgraph for 'Townsend at 7th'

# %%
from graphframes import GraphFrame

station = "Townsend at 7th"

# Filter edges
sub_edges = edges.filter((edges.src == station) | (edges.dst == station))

# Get all station IDs from sub_edges
station_ids = (
    sub_edges.select("src").union(sub_edges.select("dst"))
    .distinct()
    .withColumnRenamed("src", "id")   # standardize column name
)

# Join correctly
sub_vertices = vertices.join(station_ids, "id", "inner").distinct()

# Build subgraph
sub_g = GraphFrame(sub_vertices, sub_edges)

# Show results
print("Subgraph edges:")
sub_g.edges.show(truncate=False)

print("Subgraph vertices:")
sub_g.vertices.show(truncate=False)
# Out:
# Subgraph edges:
# +-------+--------+---------------+---------------------------------------+--------------+---------------+------------------------------------+------------+------+---------------+--------+
# |Trip ID|Duration|Start Date     |src                                    |Start Terminal|End Date       |dst                                 |End Terminal|Bike #|Subscriber Type|Zip Code|
# +-------+--------+---------------+---------------------------------------+--------------+---------------+------------------------------------+------------+------+---------------+--------+
# |913434 |283     |8/31/2015 21:19|San Francisco Caltrain 2 (330 Townsend)|69            |8/31/2015 21:24|Townsend at 7th                     |65          |521   |Subscriber     |94107   |
# |913404 |273     |8/31/2015 20:39|San Francisco Caltrain 2 (330 Townsend)|69            |8/31/2015 20:44|Townsend at 7th                     |65          |287   |Subscriber     |94107   |
# |913382 |645     |8/31/2015 20:20|Townsend at 7th                        |65            |8/31/2015 20:31|Harry Bridges Plaza (Ferry Building)|50          |270   |Subscriber     |94945   |
# |913379 |803     |8/31/2015 20:15|Spear at Folsom                        |49            |8/31/2015 20:28|Townsend at 7th                     |65          |607   |Subscriber     |94107   |
# |913371 |663     |8/31/2015 20:10|Townsend at 7th                        |65            |8/31/2015 20:21|Spear at Folsom                     |49          |405   |Subscriber     |94103   |
# |913361 |236     |8/31/2015 20:05|San Francisco Caltrain 2 (330 Townsend)|69            |8/31/2015 20:09|Townsend at 7th                     |65          |270   |Subscriber     |94107   |
# |913343 |426     |8/31/2015 19:51|5th at Howard                          |57            |8/31/2015 19:58|Townsend at 7th                     |65          |457   |Subscriber     |94107   |
# |913316 |300     |8/31/2015 19:34|San Francisco Caltrain 2 (330 Townsend)|69            |8/31/2015 19:39|Townsend at 7th                     |65          |368   |Subscriber     |94107   |
# |913296 |765     |8/31/2015 19:20|Howard at 2nd                          |63            |8/31/2015 19:33|Townsend at 7th                     |65          |564   |Subscriber     |94116   |
# +-------+--------+---------------+---------------------------------------+--------------+---------------+------------------------------------+------------+------+---------------+--------+
#
# Subgraph vertices:
# +---------------------------------------+----------+---------+-----------+---------+-------------+------------+
# |id                                     |station_id|lat      |long       |dockcount|landmark     |installation|
# +---------------------------------------+----------+---------+-----------+---------+-------------+------------+
# |San Francisco Caltrain 2 (330 Townsend)|69        |37.7766  |-122.39547 |23       |San Francisco|8/23/2013   |
# |Howard at 2nd                          |63        |37.786978|-122.398108|19       |San Francisco|8/22/2013   |
# |Harry Bridges Plaza (Ferry Building)   |50        |37.795392|-122.394203|23       |San Francisco|8/20/2013   |
# |Spear at Folsom                        |49        |37.790302|-122.390637|19       |San Francisco|8/20/2013   |
# |5th at Howard                          |57        |37.781752|-122.405127|15       |San Francisco|8/21/2013   |
# |Townsend at 7th                        |65        |37.771058|-122.402717|15       |San Francisco|8/22/2013   |
# +---------------------------------------+----------+---------+-----------+---------+-------------+------------+

# %% [markdown]
# Query 11: Triangle motifs

# %%
triangles = g.find("(a)-[e1]->(b); (b)-[e2]->(c); (c)-[e3]->(a)") \
             .filter("a.id != b.id AND b.id != c.id AND c.id != a.id")
triangles.select("a.id","b.id","c.id").show(50, truncate=False)
# Out:
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/dataframe.py:147: UserWarning: DataFrame constructor is internal. Do not directly use it.
#   warnings.warn("DataFrame constructor is internal. Do not directly use it.")
# +---------------------------------------+---------------------------------------+---------------------------------------+
# |id                                     |id                                     |id                                     |
# +---------------------------------------+---------------------------------------+---------------------------------------+
# |Embarcadero at Sansome                 |Steuart at Market                      |2nd at Townsend                        |
# |Embarcadero at Sansome                 |Market at Sansome                      |2nd at Townsend                        |
# |San Francisco Caltrain 2 (330 Townsend)|Townsend at 7th                        |Spear at Folsom                        |
# |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|2nd at Townsend                        |
# |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|Townsend at 7th                        |
# |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|2nd at South Park                      |
# |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|2nd at South Park                      |
# |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|Townsend at 7th                        |
# |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|Townsend at 7th                        |
# |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|Townsend at 7th                        |
# |San Francisco Caltrain 2 (330 Townsend)|Townsend at 7th                        |Spear at Folsom                        |
# |Market at Sansome                      |2nd at Townsend                        |Howard at 2nd                          |
# |Market at Sansome                      |2nd at Townsend                        |Embarcadero at Sansome                 |
# |2nd at Townsend                        |Embarcadero at Sansome                 |Market at Sansome                      |
# |2nd at Townsend                        |Embarcadero at Sansome                 |Steuart at Market                      |
# |Townsend at 7th                        |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|
# |Townsend at 7th                        |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|
# |Townsend at 7th                        |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|
# |Townsend at 7th                        |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|
# |Howard at 2nd                          |San Francisco Caltrain 2 (330 Townsend)|2nd at Townsend                        |
# |Howard at 2nd                          |San Francisco Caltrain 2 (330 Townsend)|2nd at South Park                      |
# |Howard at 2nd                          |San Francisco Caltrain 2 (330 Townsend)|2nd at South Park                      |
# |San Francisco Caltrain 2 (330 Townsend)|Townsend at 7th                        |Spear at Folsom                        |
# |Howard at 2nd                          |Market at 4th                          |2nd at Townsend                        |
# |San Francisco Caltrain 2 (330 Townsend)|2nd at South Park                      |Howard at 2nd                          |
# |San Francisco Caltrain 2 (330 Townsend)|2nd at South Park                      |Spear at Folsom                        |
# |San Francisco Caltrain 2 (330 Townsend)|2nd at South Park                      |Howard at 2nd                          |
# |San Francisco Caltrain 2 (330 Townsend)|2nd at South Park                      |Spear at Folsom                        |
# |Market at 4th                          |2nd at Townsend                        |Howard at 2nd                          |
# |San Francisco Caltrain 2 (330 Townsend)|Townsend at 7th                        |Spear at Folsom                        |
# |Steuart at Market                      |2nd at Townsend                        |Embarcadero at Sansome                 |
# |Howard at 2nd                          |Market at Sansome                      |2nd at Townsend                        |
# |2nd at Townsend                        |Howard at 2nd                          |Market at Sansome                      |
# |2nd at Townsend                        |Howard at 2nd                          |Market at 4th                          |
# |2nd at Townsend                        |Howard at 2nd                          |San Francisco Caltrain 2 (330 Townsend)|
# |San Francisco Caltrain 2 (330 Townsend)|2nd at Townsend                        |Spear at Folsom                        |
# |San Francisco Caltrain 2 (330 Townsend)|2nd at Townsend                        |Howard at 2nd                          |
# |2nd at South Park                      |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|
# |2nd at South Park                      |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|
# |2nd at Townsend                        |Spear at Folsom                        |San Francisco Caltrain 2 (330 Townsend)|
# |2nd at South Park                      |Howard at 2nd                          |San Francisco Caltrain 2 (330 Townsend)|
# |2nd at South Park                      |Howard at 2nd                          |San Francisco Caltrain 2 (330 Townsend)|
# +---------------------------------------+---------------------------------------+---------------------------------------+

# %% [markdown]
# Query 12: Paths of length 3 from 'Townsend at 7th'

# %%
paths3 = g.find("(a)-[e1]->(b); (b)-[e2]->(c); (c)-[e3]->(d)") \
          .filter(f"a.id = '{station}'") \
          .filter("a.id != b.id AND b.id != c.id AND c.id != d.id")
paths3.select("a.id","b.id","c.id","d.id").show(50, truncate=False)
# Out:
# +---------------+------------------------------------+----------------------------------------+---------------------------------------------+
# |id             |id                                  |id                                      |id                                           |
# +---------------+------------------------------------+----------------------------------------+---------------------------------------------+
# |Townsend at 7th|Harry Bridges Plaza (Ferry Building)|2nd at Townsend                         |Spear at Folsom                              |
